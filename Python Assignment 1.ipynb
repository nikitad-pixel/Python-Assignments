# %%
#1
students = {
    101: {"name": "Riya", "branch": "CSE", "marks": 85},
    102: {"name": "Priya", "branch": "ECE", "marks": 90}
}

students[103] = {"name": "Akash", "branch": "ME", "marks": 78}

del students[102]
students[101]["marks"] = 88

student_tuple = (101, "Riya", "CSE", 88)
student_list = [103, "Akash", "ME", 78]

print("Final Student Records:")
for roll_no, details in students.items():
    print(roll_no, details)
# Out:
# Final Student Records:
# 101 {'name': 'Riya', 'branch': 'CSE', 'marks': 88}
# 103 {'name': 'Akash', 'branch': 'ME', 'marks': 78}
